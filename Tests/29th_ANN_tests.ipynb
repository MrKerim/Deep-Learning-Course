# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.15.0

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test , x_test = x_test / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128,),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer ="adam" ,loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
result = model.fit(x_train, y_train, epochs=10,validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 1s 681us/step - loss: 0.6250 - accuracy: 0.8134 - val_loss: 0.7101 - val_accuracy: 0.8446
# Epoch 2/10
# 1875/1875 [==============================] - 1s 616us/step - loss: 0.4384 - accuracy: 0.8668 - val_loss: 0.5058 - val_accuracy: 0.8854
# Epoch 3/10
# 1875/1875 [==============================] - 1s 617us/step - loss: 0.4092 - accuracy: 0.8731 - val_loss: 0.4022 - val_accuracy: 0.8988
# Epoch 4/10
# 1875/1875 [==============================] - 1s 606us/step - loss: 0.3780 - accuracy: 0.8839 - val_loss: 0.3501 - val_accuracy: 0.9059
# Epoch 5/10
# 1875/1875 [==============================] - 1s 615us/step - loss: 0.3615 - accuracy: 0.8889 - val_loss: 0.3312 - val_accuracy: 0.9081
# Epoch 6/10
# 1875/1875 [==============================] - 1s 620us/step - loss: 0.3416 - accuracy: 0.8939 - val_loss: 0.3045 - val_accuracy: 0.9149
# Epoch 7/10
# 1875/1875 [==============================] - 1s 616us/step - loss: 0.3388 - accuracy: 0.8955 - val_loss: 0.2904 - val_accuracy: 0.9217
# Epoch 8/10
# 1875/1875 [==============================] - 1s 610us/step - loss: 0.3334 - accuracy: 0.8975 - val_loss: 0.2736 - val_accuracy: 0.9214
# Epoch 9/10
# 1875/1875 [==============================] - 1s 611us/step - loss: 0.3151 - accuracy: 0.9037 - val_loss: 0.2591 - val_accuracy: 0.9306
# Epoch 10/10
# 1875/1875 [==============================] - 1s 604us/step - loss: 0.3001 - accuracy: 0.9067 - val_loss: 0.2508 - val_accuracy: 0.9266

# %%
plt.plot(result.history['accuracy'], label='accuracy')

# %%
y = model.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 309us/step

# %%
a = np.random.randint(0,10000)
print(y[a].argmax())
plt.imshow(x_test[a], cmap='gray')
# Out:
# 3
